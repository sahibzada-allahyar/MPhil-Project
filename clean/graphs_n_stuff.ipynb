# %%
from nestedsampling.samplers import NSrun
import numpy as np
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
import sys
import pandas as pd

def loglikelihood(x):
    mean = np.array([0.5, 0.5])
    cov = np.array([[0.01, 0.0], [0.0, 0.01 ]])
    logL = multivariate_normal.logpdf(x, mean=mean, cov=cov) + np.random.normal(0,sigma_)
    prob = np.random.rand()
    if prob>0.99999: 
        print('loglikelihood is using sigma_ as'+str(sigma_))
    return logL


def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))/(sig*np.sqrt(2*np.pi))


# sigma_ = 0
# mh1= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0],[1,1]],ndims=2,tol=1e-30)

# fig,axs=mh1.MCMC2d(parameters=['x0','x1'],label_='deterministic orthodox')

# sigma_=0.25

# for sigma_ in [0.25,20.0,100.0]:    
#     mh_err= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0], [1,1]], ndims=2,tol=1e-35)
#     mh_err.MCMC2d(parameters=axs,label_='non-deterministic with std error='+str(sigma_))


# handles, labels = axs['x0']['x0'].get_legend_handles_labels()
# leg = fig.legend(handles, labels)
# fig.tight_layout()
# plt.show()


# plt.figure(0)
# x = np.linspace(0,1,3000)
  
# mean = 0.5, 
# sigg = 0.1
# y = gaussian(x, mu=mean, sig=sigg)



# axs['x0']['x0'].plot(x,y,label= 'gaussian')

# axs['x1']['x1'].plot(x,y,label= 'gaussian')


# handles, labels = axs['x0']['x1'].get_legend_handles_labels()
# leg = fig.legend(handles, labels)
# fig.tight_layout()
# plt.show()

# sys.exit(0)

#####################################################
'''%Metropolis hastings below'''


sigma_ = 0.0
mh= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0],[1,1]],ndims=2,Metropolis=True)

fig,axs=mh.MCMC2d(parameters=['x0','x1'],label_='deterministic Metropolis')

for sigma_ in [0.25,20.0,100.0]:    
    mh2= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0], [1,1]], ndims=2,Metropolis=True)
    mh2.MCMC2d(parameters=axs,label_='non-deterministic Metropolis with std error='+str(sigma_))
# with std error='+str(sigma_))


# x = np.linspace(0,1,3000)

# mean = 0.5, 
# sigg = 0.1
# y = gaussian(x, mu=mean, sig=sigg)

# axs['x0']['x0'].plot(x,y,color='purple')
    


# axs['x1']['x1'].plot(x,y,color='purple')
    


handles, labels = axs['x0']['x0'].get_legend_handles_labels()
leg = fig.legend(handles, labels)
fig.tight_layout()
plt.show()


plt.figure(0)

# plt.hist(mh1.logZ_int(200),label= 'ORTHODOX', alpha=0.5)
# plt.hist(mh2.logZ_int(200),label= 'MCMC',alpha=0.5)

# plt.legend(loc="upper left")








# # df = pd.DataFrame({
# #     'x_vals':x_
# # })
# # df['Actual Gaussian']=y

# # df.plot(x=x_,y='Actual Gaussian',ax=axs['x0']['x0'],color='purple')

# # df.plot(x=x_,y='Actual Gaussian',ax=axs['x1']['x1'],color='purple')
# Out:
# tolerance chosen as1e-30
# 100%|██████████████████████████████████████| 1375/1375 [00:05<00:00, 260.08it/s]
# random walk steps are12
# -13231.56681289203should be same as0.07846390893248056
# tolerance chosen as1e-30
# 100%|██████████████████████████████████████| 1375/1375 [00:08<00:00, 159.71it/s]
# random walk steps are12
# -13473.175830587299should be same as-0.3089568315664879
# tolerance chosen as1e-30
# 100%|██████████████████████████████████████| 1375/1375 [00:09<00:00, 142.24it/s]
# random walk steps are12
# -11192.446044819497should be same as13.888497756871034
# tolerance chosen as1e-30
# 100%|██████████████████████████████████████| 1375/1375 [00:10<00:00, 136.61it/s]
# random walk steps are12
# 20580.105699637537should be same as118.50767464882732

# %%
from nestedsampling.samplers import NSrun
import numpy as np
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
import sys
import pandas as pd

def loglikelihood(x):
    mean = np.array([0.5, 0.5])
    cov = np.array([[0.01, 0.0], [0.0, 0.01 ]])
    logL = multivariate_normal.logpdf(x, mean=mean, cov=cov) + np.random.normal(0,sigma_)
    prob = np.random.rand()
    if prob>0.99999: 
        print('loglikelihood is using sigma_ as'+str(sigma_))
    return logL


def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))/(sig*np.sqrt(2*np.pi))


# sigma_ = 0
# mh1= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0],[1,1]],ndims=2,tol=1e-30)

# fig,axs=mh1.MCMC2d(parameters=['x0','x1'],label_='deterministic orthodox')

# sigma_=0.25

# for sigma_ in [0.25,20.0,100.0]:    
#     mh_err= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0], [1,1]], ndims=2,tol=1e-35)
#     mh_err.MCMC2d(parameters=axs,label_='non-deterministic with std error='+str(sigma_))


# handles, labels = axs['x0']['x0'].get_legend_handles_labels()
# leg = fig.legend(handles, labels)
# fig.tight_layout()
# plt.show()


# plt.figure(0)
# x = np.linspace(0,1,3000)
  
# mean = 0.5, 
# sigg = 0.1
# y = gaussian(x, mu=mean, sig=sigg)



# axs['x0']['x0'].plot(x,y,label= 'gaussian')

# axs['x1']['x1'].plot(x,y,label= 'gaussian')


# handles, labels = axs['x0']['x1'].get_legend_handles_labels()
# leg = fig.legend(handles, labels)
# fig.tight_layout()
# plt.show()

# sys.exit(0)

#####################################################
'''%Metropolis hastings below'''


sigma_ = 0.0
mh= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0],[1,1]],ndims=2,Metropolis=True)

fig,axs=mh.MCMC2d(parameters=['x0','x1'],label_='deterministic Metropolis')

for sigma_ in [0.25,20.0,100.0]:    
    mh2= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0], [1,1]], ndims=2,Metropolis=True)
    mh2.MCMC2d(parameters=axs,label_='non-deterministic Metropolis with std error='+str(sigma_))
# with std error='+str(sigma_))


# x = np.linspace(0,1,3000)

# mean = 0.5, 
# sigg = 0.1
# y = gaussian(x, mu=mean, sig=sigg)

# axs['x0']['x0'].plot(x,y,color='purple')
    


# axs['x1']['x1'].plot(x,y,color='purple')
    


handles, labels = axs['x0']['x0'].get_legend_handles_labels()
leg = fig.legend(handles, labels)
fig.tight_layout()
plt.show()


plt.figure(0)

# plt.hist(mh1.logZ_int(200),label= 'ORTHODOX', alpha=0.5)
# plt.hist(mh2.logZ_int(200),label= 'MCMC',alpha=0.5)

# plt.legend(loc="upper left")








# # df = pd.DataFrame({
# #     'x_vals':x_
# # })
# # df['Actual Gaussian']=y

# # df.plot(x=x_,y='Actual Gaussian',ax=axs['x0']['x0'],color='purple')

# # df.plot(x=x_,y='Actual Gaussian',ax=axs['x1']['x1'],color='purple')
# Out:
# tolerance chosen as1e-30
#  26%|██████████▍                             | 359/1375 [00:08<00:24, 42.12it/s]
# loglikelihood is using sigma_ as0.0
#  43%|█████████████████▏                      | 589/1375 [00:14<00:18, 41.49it/s]
# loglikelihood is using sigma_ as0.0
#  81%|███████████████████████████████▌       | 1111/1375 [00:26<00:06, 40.24it/s]
# loglikelihood is using sigma_ as0.0
# 100%|███████████████████████████████████████| 1375/1375 [00:33<00:00, 41.49it/s]
# random walk steps are125
# -12973.300502714099should be same as0.04676531821553631
# tolerance chosen as1e-30
#   2%|▋                                        | 25/1375 [00:00<00:32, 41.28it/s]
# loglikelihood is using sigma_ as0.25
#   9%|███▋                                    | 127/1375 [00:03<00:30, 40.67it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/yz/c010y81949927ct_45zs0n8w0000gn/T/ipykernel_2579/1106652539.py in <module>
#      69
#      70 for sigma_ in [0.25,20.0,100.0]:
# ---> 71     mh2= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0], [1,1]], ndims=2,Metropolis=True)
#      72     mh2.MCMC2d(parameters=axs,label_='non-deterministic Metropolis with std error='+str(sigma_))
#      73 # with std error='+str(sigma_))
#
# ~/Documents/codes/GitHub/clean/nestedsampling/samplers.py in __init__(self, loglikelihood, prior_bounds, ndims, nlive, Metropolis, num_repeats, tol)
#      51                     self.frac= np.log(0.5*(np.exp(self.logL[-1])+np.exp(self.logL[-2]))*(np.exp(self.logX[-2])-np.exp(self.logX[-1])))
#      52                     self.logZ_tester += self.frac
# ---> 53                     cond = self.breaking_criterion()
#      54                     if cond:
#      55                         print(cond)
#
# ~/Documents/codes/GitHub/clean/nestedsampling/samplers.py in breaking_criterion(self)
#      86         #print('wills logZ is'+str(logZ__))
#      87         self.frac= np.log(0.5*(np.exp(self.logL[-1])+np.exp(self.logL[-2]))*(np.exp(self.logX[-2])-np.exp(self.logX[-1])))
# ---> 88         self.logZval = self.logZ()
#      89         self.logZ_increment= (self.frac)/(self.logZval)
#      90         #print('logZ_increment is'+str(self.logZ_increment))
#
# ~/Documents/codes/GitHub/clean/nestedsampling/samplers.py in logZ(self)
#     116
#     117     def logZ(self):
# --> 118         self.logX_powerlaw()
#     119         logsum_L=logsumexp([self.logL[1:],self.logL[:-1]],axis=0)
#     120         logdiff_X=logsumexp([self.logX[1:],self.logX[:-1]],axis=0,b=np.array([-1,1])[:,None])
#
# ~/Documents/codes/GitHub/clean/nestedsampling/samplers.py in logX_powerlaw(self)
#     105     def logX_powerlaw(self):
#     106         self.ndead = len(self.logL)
# --> 107         t = powerlaw(self.nlive).rvs(self.ndead)
#     108         self.logX = np.log(t).cumsum()
#     109         return self.logX
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py in __call__(self, *args, **kwds)
#     863
#     864     def __call__(self, *args, **kwds):
# --> 865         return self.freeze(*args, **kwds)
#     866     __call__.__doc__ = freeze.__doc__
#     867
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py in freeze(self, *args, **kwds)
#     860
#     861         """
# --> 862         return rv_frozen(self, *args, **kwds)
#     863
#     864     def __call__(self, *args, **kwds):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py in __init__(self, dist, *args, **kwds)
#     437
#     438         # create a new instance
# --> 439         self.dist = dist.__class__(**dist._updated_ctor_param())
#     440
#     441         shapes, _, _ = self.dist._parse_args(*args, **kwds)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py in __init__(self, momtype, a, b, xtol, badvalue, name, longname, shapes, extradoc, seed)
#    1719                                   locscale_in='loc=0, scale=1',
#    1720                                   locscale_out='loc, scale')
# -> 1721         self._attach_methods()
#    1722
#    1723         if longname is None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py in _attach_methods(self)
#    1754         """
#    1755         # _attach_methods is responsible for calling _attach_argparser_methods
# -> 1756         self._attach_argparser_methods()
#    1757
#    1758         # nin correction
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py in _attach_argparser_methods(self)
#     706         """
#     707         ns = {}
# --> 708         exec(self._parse_arg_template, ns)
#     709         # NB: attach to the instance, not class
#     710         for name in ['_parse_args', '_parse_args_stats', '_parse_args_rvs']:
#
# <string> in <module>
#
# KeyboardInterrupt:

# %%
def loglikelihood(x):
    mean = np.array([0.5, 0.5])
    cov = np.array([[0.01, 0.0], [0.0, 0.01 ]])
    logL = multivariate_normal.logpdf(x, mean=mean, cov=cov) + np.random.rand()*sigma_
    prob = np.random.rand()
    if prob>0.99999: 
        print('loglikelihood is using sigma_ as'+str(sigma_))
    return logL


sigma_ = 0
mh1= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0],[1,1]],ndims=2,tol=1e-30)

fig,axs=mh1.MCMC2d(parameters=['x0','x1'],label_='deterministic orthodox')

sigma_=0.25

for sigma_ in [0.25,20.0,100.0]:    
    mh_err= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0], [1,1]], ndims=2,tol=1e-35)
    mh_err.MCMC2d(parameters=axs,label_='non-deterministic with std error='+str(sigma_))


handles, labels = axs['x0']['x0'].get_legend_handles_labels()
leg = fig.legend(handles, labels)
fig.tight_layout()
plt.show()


plt.figure(0)
# Out:
# tolerance chosen as1e-30
#  70%|███████████████████████████▉            | 960/1375 [00:16<00:45,  9.19it/s]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  71%|████████████████████████████▎           | 973/1375 [00:19<01:40,  4.01it/s]
# loglikelihood is using sigma_ as0
#  73%|█████████████████████████████           | 999/1375 [00:23<00:58,  6.40it/s]
# loglikelihood is using sigma_ as0
#  75%|█████████████████████████████          | 1025/1375 [00:28<00:55,  6.26it/s]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  75%|█████████████████████████████▎         | 1033/1375 [00:30<01:20,  4.27it/s]
# loglikelihood is using sigma_ as0
#  78%|██████████████████████████████▎        | 1067/1375 [00:40<02:43,  1.88it/s]
# loglikelihood is using sigma_ as0
#  78%|██████████████████████████████▎        | 1068/1375 [00:42<04:13,  1.21it/s]
# loglikelihood is using sigma_ as0
#  78%|██████████████████████████████▍        | 1071/1375 [00:44<04:27,  1.14it/s]
# loglikelihood is using sigma_ as0
#  80%|███████████████████████████████        | 1097/1375 [00:54<02:55,  1.58it/s]
# loglikelihood is using sigma_ as0
#  80%|███████████████████████████████▏       | 1100/1375 [00:56<02:18,  1.99it/s]
# loglikelihood is using sigma_ as0
#  81%|███████████████████████████████▋       | 1118/1375 [01:04<01:58,  2.18it/s]
# loglikelihood is using sigma_ as0
#  82%|████████████████████████████████       | 1130/1375 [01:12<03:35,  1.13it/s]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  83%|████████████████████████████████▎      | 1138/1375 [01:20<03:34,  1.11it/s]
# loglikelihood is using sigma_ as0
#  85%|█████████████████████████████████▏     | 1170/1375 [01:39<05:41,  1.67s/it]
# loglikelihood is using sigma_ as0
#  86%|█████████████████████████████████▍     | 1180/1375 [01:44<01:54,  1.71it/s]
# loglikelihood is using sigma_ as0
#  86%|█████████████████████████████████▌     | 1185/1375 [01:49<02:27,  1.29it/s]
# loglikelihood is using sigma_ as0
#  87%|█████████████████████████████████▉     | 1195/1375 [01:54<01:21,  2.21it/s]
# loglikelihood is using sigma_ as0
#  87%|██████████████████████████████████     | 1201/1375 [01:58<01:44,  1.67it/s]
# loglikelihood is using sigma_ as0
#  88%|██████████████████████████████████▍    | 1215/1375 [02:12<03:26,  1.29s/it]
# loglikelihood is using sigma_ as0
#  89%|██████████████████████████████████▊    | 1227/1375 [02:18<01:07,  2.19it/s]
# loglikelihood is using sigma_ as0
#  90%|███████████████████████████████████    | 1236/1375 [02:27<02:19,  1.00s/it]
# loglikelihood is using sigma_ as0
#  91%|███████████████████████████████████▌   | 1255/1375 [02:48<02:05,  1.05s/it]
# loglikelihood is using sigma_ as0
#  92%|████████████████████████████████████   | 1271/1375 [03:01<01:24,  1.23it/s]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  93%|████████████████████████████████████▏  | 1276/1375 [03:10<02:51,  1.74s/it]
# loglikelihood is using sigma_ as0
#  94%|████████████████████████████████████▌  | 1287/1375 [03:23<02:00,  1.37s/it]
# loglikelihood is using sigma_ as0
#  94%|████████████████████████████████████▋  | 1292/1375 [03:29<01:25,  1.03s/it]
# loglikelihood is using sigma_ as0
#  94%|████████████████████████████████████▋  | 1295/1375 [03:35<01:44,  1.30s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  94%|████████████████████████████████████▊  | 1299/1375 [03:38<01:07,  1.13it/s]
# loglikelihood is using sigma_ as0
#  95%|████████████████████████████████████▉  | 1301/1375 [03:40<01:08,  1.08it/s]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  95%|████████████████████████████████████▉  | 1304/1375 [03:53<03:38,  3.08s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  95%|█████████████████████████████████████  | 1306/1375 [03:56<02:43,  2.37s/it]
# loglikelihood is using sigma_ as0
#  95%|█████████████████████████████████████  | 1307/1375 [04:03<04:06,  3.62s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  95%|█████████████████████████████████████▏ | 1310/1375 [04:07<02:04,  1.91s/it]
# loglikelihood is using sigma_ as0
#  96%|█████████████████████████████████████▎ | 1316/1375 [04:14<01:11,  1.21s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  96%|█████████████████████████████████████▌ | 1324/1375 [04:25<00:56,  1.11s/it]
# loglikelihood is using sigma_ as0
#  96%|█████████████████████████████████████▌ | 1325/1375 [04:28<01:16,  1.54s/it]
# loglikelihood is using sigma_ as0
#  97%|█████████████████████████████████████▋ | 1327/1375 [04:29<00:58,  1.21s/it]
# loglikelihood is using sigma_ as0
#  97%|█████████████████████████████████████▊ | 1332/1375 [04:37<00:53,  1.24s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  97%|█████████████████████████████████████▊ | 1334/1375 [04:55<03:14,  4.73s/it]
# loglikelihood is using sigma_ as0
#  97%|█████████████████████████████████████▉ | 1336/1375 [05:03<02:46,  4.27s/it]
# loglikelihood is using sigma_ as0
#  97%|█████████████████████████████████████▉ | 1338/1375 [05:11<02:34,  4.19s/it]
# loglikelihood is using sigma_ as0
#  98%|██████████████████████████████████████ | 1341/1375 [05:18<01:30,  2.66s/it]
# loglikelihood is using sigma_ as0
#  98%|██████████████████████████████████████▏| 1348/1375 [05:28<00:28,  1.04s/it]
# loglikelihood is using sigma_ as0
#  98%|██████████████████████████████████████▎| 1350/1375 [05:33<00:42,  1.69s/it]
# loglikelihood is using sigma_ as0
#  98%|██████████████████████████████████████▎| 1351/1375 [05:35<00:43,  1.80s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  98%|██████████████████████████████████████▍| 1353/1375 [05:39<00:40,  1.85s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  98%|██████████████████████████████████████▍| 1354/1375 [05:48<01:18,  3.76s/it]
# loglikelihood is using sigma_ as0
#  99%|██████████████████████████████████████▍| 1355/1375 [05:53<01:26,  4.31s/it]
# loglikelihood is using sigma_ as0
#  99%|██████████████████████████████████████▍| 1357/1375 [06:01<01:10,  3.92s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  99%|██████████████████████████████████████▋| 1362/1375 [06:13<00:26,  2.02s/it]
# loglikelihood is using sigma_ as0
#  99%|██████████████████████████████████████▋| 1363/1375 [06:18<00:35,  2.96s/it]
# loglikelihood is using sigma_ as0
#  99%|██████████████████████████████████████▋| 1364/1375 [06:24<00:40,  3.69s/it]
# loglikelihood is using sigma_ as0
# 100%|███████████████████████████████████████| 1375/1375 [07:11<00:00,  3.19it/s]
# -13131.811316411373should be same as-0.04192947053219065
# tolerance chosen as1e-35
#  76%|█████████████████████████████▍         | 1040/1375 [00:34<00:46,  7.20it/s]
# loglikelihood is using sigma_ as0.25
#  77%|██████████████████████████████▏        | 1063/1375 [00:39<01:16,  4.06it/s]
# loglikelihood is using sigma_ as0.25
#  80%|███████████████████████████████        | 1097/1375 [00:55<03:03,  1.52it/s]
# loglikelihood is using sigma_ as0.25
#  81%|███████████████████████████████▌       | 1111/1375 [01:01<01:34,  2.80it/s]
# loglikelihood is using sigma_ as0.25
#  84%|████████████████████████████████▊      | 1159/1375 [01:24<01:42,  2.12it/s]
# loglikelihood is using sigma_ as0.25
#  84%|████████████████████████████████▉      | 1161/1375 [01:26<02:08,  1.66it/s]
# loglikelihood is using sigma_ as0.25
#  85%|████████████████████████████████▉      | 1162/1375 [01:28<03:08,  1.13it/s]
# loglikelihood is using sigma_ as0.25
#  85%|█████████████████████████████████      | 1167/1375 [01:29<01:28,  2.36it/s]
# loglikelihood is using sigma_ as0.25
#  86%|█████████████████████████████████▍     | 1178/1375 [01:38<01:48,  1.82it/s]
# loglikelihood is using sigma_ as0.25
#  86%|█████████████████████████████████▌     | 1184/1375 [01:44<02:52,  1.11it/s]
# loglikelihood is using sigma_ as0.25
#  86%|█████████████████████████████████▋     | 1186/1375 [01:46<02:55,  1.08it/s]
# loglikelihood is using sigma_ as0.25
#  86%|█████████████████████████████████▋     | 1187/1375 [01:47<03:04,  1.02it/s]
# loglikelihood is using sigma_ as0.25
#  86%|█████████████████████████████████▋     | 1188/1375 [01:50<04:36,  1.48s/it]
# loglikelihood is using sigma_ as0.25
#  87%|█████████████████████████████████▊     | 1194/1375 [01:56<03:19,  1.10s/it]
# loglikelihood is using sigma_ as0.25
#  88%|██████████████████████████████████▍    | 1215/1375 [02:14<03:47,  1.42s/it]
# loglikelihood is using sigma_ as0.25
# loglikelihood is using sigma_ as0.25
#  89%|██████████████████████████████████▌    | 1220/1375 [02:20<02:48,  1.09s/it]
# loglikelihood is using sigma_ as0.25
#  89%|██████████████████████████████████▋    | 1223/1375 [02:26<03:27,  1.36s/it]
# loglikelihood is using sigma_ as0.25
#  89%|██████████████████████████████████▋    | 1224/1375 [02:27<03:45,  1.49s/it]
# loglikelihood is using sigma_ as0.25
#  89%|██████████████████████████████████▊    | 1228/1375 [02:33<03:53,  1.59s/it]
# loglikelihood is using sigma_ as0.25
#  89%|██████████████████████████████████▉    | 1230/1375 [02:35<02:37,  1.09s/it]
# loglikelihood is using sigma_ as0.25
#  91%|███████████████████████████████████▎   | 1245/1375 [02:55<02:56,  1.36s/it]
# loglikelihood is using sigma_ as0.25
#  91%|███████████████████████████████████▎   | 1246/1375 [02:58<03:56,  1.83s/it]
# loglikelihood is using sigma_ as0.25
#  91%|███████████████████████████████████▍   | 1248/1375 [03:01<03:41,  1.75s/it]
# loglikelihood is using sigma_ as0.25
#  91%|███████████████████████████████████▋   | 1257/1375 [03:09<01:27,  1.34it/s]
# loglikelihood is using sigma_ as0.25
#  92%|███████████████████████████████████▉   | 1265/1375 [03:16<01:03,  1.73it/s]
# loglikelihood is using sigma_ as0.25
#  93%|████████████████████████████████████▏  | 1277/1375 [03:33<03:55,  2.40s/it]
# loglikelihood is using sigma_ as0.25
#  93%|████████████████████████████████████▎  | 1281/1375 [03:39<02:59,  1.91s/it]
# loglikelihood is using sigma_ as0.25
# loglikelihood is using sigma_ as0.25
#  94%|████████████████████████████████████▍  | 1286/1375 [03:54<03:08,  2.12s/it]
# loglikelihood is using sigma_ as0.25
#  94%|████████████████████████████████████▊  | 1297/1375 [04:10<01:21,  1.05s/it]
# loglikelihood is using sigma_ as0.25
#  95%|████████████████████████████████████▊  | 1300/1375 [04:20<02:35,  2.08s/it]
# loglikelihood is using sigma_ as0.25
#  95%|█████████████████████████████████████▏ | 1313/1375 [04:48<01:21,  1.32s/it]
# loglikelihood is using sigma_ as0.25
#  96%|█████████████████████████████████████▎ | 1314/1375 [04:49<01:17,  1.27s/it]
# loglikelihood is using sigma_ as0.25
#  96%|█████████████████████████████████████▎ | 1317/1375 [04:55<01:31,  1.58s/it]
# loglikelihood is using sigma_ as0.25
#  96%|█████████████████████████████████████▌ | 1323/1375 [05:01<01:00,  1.17s/it]
# loglikelihood is using sigma_ as0.25
#  97%|█████████████████████████████████████▉ | 1338/1375 [05:29<01:08,  1.85s/it]
# loglikelihood is using sigma_ as0.25
#  98%|██████████████████████████████████████ | 1341/1375 [05:37<01:20,  2.35s/it]
# loglikelihood is using sigma_ as0.25
#  98%|██████████████████████████████████████ | 1342/1375 [05:42<01:42,  3.10s/it]
# loglikelihood is using sigma_ as0.25
#  98%|██████████████████████████████████████▏| 1348/1375 [05:59<01:14,  2.76s/it]
# loglikelihood is using sigma_ as0.25
#  98%|██████████████████████████████████████▎| 1351/1375 [06:13<01:26,  3.58s/it]
# loglikelihood is using sigma_ as0.25
#  99%|██████████████████████████████████████▍| 1357/1375 [06:26<00:30,  1.70s/it]
# loglikelihood is using sigma_ as0.25
#  99%|██████████████████████████████████████▌| 1359/1375 [06:28<00:20,  1.25s/it]
# loglikelihood is using sigma_ as0.25
#  99%|██████████████████████████████████████▋| 1363/1375 [06:38<00:28,  2.38s/it]
# loglikelihood is using sigma_ as0.25
#  99%|██████████████████████████████████████▋| 1365/1375 [06:41<00:18,  1.84s/it]
# loglikelihood is using sigma_ as0.25
#  99%|██████████████████████████████████████▋| 1366/1375 [07:02<01:09,  7.74s/it]
# loglikelihood is using sigma_ as0.25
#  99%|██████████████████████████████████████▊| 1367/1375 [07:03<00:45,  5.64s/it]
# loglikelihood is using sigma_ as0.25
#  99%|██████████████████████████████████████▊| 1368/1375 [07:05<00:32,  4.69s/it]
# loglikelihood is using sigma_ as0.25
# 100%|██████████████████████████████████████▉| 1372/1375 [07:17<00:10,  3.45s/it]
# loglikelihood is using sigma_ as0.25
# 100%|██████████████████████████████████████▉| 1373/1375 [07:22<00:07,  3.80s/it]
# loglikelihood is using sigma_ as0.25
# loglikelihood is using sigma_ as0.25
# loglikelihood is using sigma_ as0.25
# loglikelihood is using sigma_ as0.25
# 100%|██████████████████████████████████████▉| 1374/1375 [07:39<00:07,  7.77s/it]
# loglikelihood is using sigma_ as0.25
# 100%|███████████████████████████████████████| 1375/1375 [07:46<00:00,  2.94it/s]
# -13011.925323346011should be same as0.16725588367678945
# tolerance chosen as1e-35
#  56%|██████████████████████▍                 | 770/1375 [00:05<00:24, 24.35it/s]
# loglikelihood is using sigma_ as20.0
# loglikelihood is using sigma_ as20.0
#  62%|████████████████████████▊               | 854/1375 [00:09<00:24, 21.11it/s]
# loglikelihood is using sigma_ as20.0
#  74%|████████████████████████████▋          | 1013/1375 [00:32<01:11,  5.03it/s]
# loglikelihood is using sigma_ as20.0
#  74%|████████████████████████████▊          | 1017/1375 [00:34<01:37,  3.67it/s]
# loglikelihood is using sigma_ as20.0
#  76%|█████████████████████████████▋         | 1045/1375 [00:43<01:45,  3.13it/s]
# loglikelihood is using sigma_ as20.0
#  77%|██████████████████████████████         | 1059/1375 [00:47<01:21,  3.86it/s]
# loglikelihood is using sigma_ as20.0
#  79%|██████████████████████████████▋        | 1082/1375 [00:54<02:32,  1.92it/s]
# loglikelihood is using sigma_ as20.0
#  81%|███████████████████████████████▍       | 1107/1375 [01:07<02:31,  1.77it/s]
# loglikelihood is using sigma_ as20.0
#  83%|████████████████████████████████▏      | 1136/1375 [01:16<01:50,  2.15it/s]
# loglikelihood is using sigma_ as20.0
#  84%|████████████████████████████████▌      | 1150/1375 [01:22<01:34,  2.38it/s]
# loglikelihood is using sigma_ as20.0
#  84%|████████████████████████████████▊      | 1159/1375 [01:26<00:49,  4.38it/s]
# loglikelihood is using sigma_ as20.0
#  85%|█████████████████████████████████      | 1165/1375 [01:30<01:34,  2.23it/s]
# loglikelihood is using sigma_ as20.0
#  85%|█████████████████████████████████▏     | 1172/1375 [01:37<02:43,  1.24it/s]
# loglikelihood is using sigma_ as20.0
#  88%|██████████████████████████████████▎    | 1208/1375 [02:06<01:41,  1.65it/s]
# loglikelihood is using sigma_ as20.0
#  88%|██████████████████████████████████▎    | 1210/1375 [02:08<02:19,  1.18it/s]
# loglikelihood is using sigma_ as20.0
#  90%|███████████████████████████████████    | 1236/1375 [02:30<01:51,  1.25it/s]
# loglikelihood is using sigma_ as20.0
#  90%|███████████████████████████████████    | 1237/1375 [02:31<02:20,  1.02s/it]
# loglikelihood is using sigma_ as20.0
#  90%|███████████████████████████████████    | 1238/1375 [02:32<02:13,  1.02it/s]
# loglikelihood is using sigma_ as20.0
#  91%|███████████████████████████████████▎   | 1245/1375 [02:40<01:43,  1.26it/s]
# loglikelihood is using sigma_ as20.0
#  91%|███████████████████████████████████▌   | 1252/1375 [02:51<02:50,  1.39s/it]
# loglikelihood is using sigma_ as20.0
#  91%|███████████████████████████████████▌   | 1253/1375 [03:00<07:10,  3.53s/it]
# loglikelihood is using sigma_ as20.0
# loglikelihood is using sigma_ as20.0
#  92%|████████████████████████████████████   | 1271/1375 [03:17<01:18,  1.32it/s]
# loglikelihood is using sigma_ as20.0
# loglikelihood is using sigma_ as20.0
#  93%|████████████████████████████████████▏  | 1275/1375 [03:23<02:26,  1.46s/it]
# loglikelihood is using sigma_ as20.0
#  93%|████████████████████████████████████▏  | 1277/1375 [03:26<02:30,  1.54s/it]
# loglikelihood is using sigma_ as20.0
#  93%|████████████████████████████████████▎  | 1279/1375 [03:30<02:37,  1.64s/it]
# loglikelihood is using sigma_ as20.0
#  93%|████████████████████████████████████▎  | 1281/1375 [03:34<03:04,  1.96s/it]
# loglikelihood is using sigma_ as20.0
#  94%|████████████████████████████████████▍  | 1286/1375 [03:42<02:33,  1.73s/it]
# loglikelihood is using sigma_ as20.0
# loglikelihood is using sigma_ as20.0
#  94%|████████████████████████████████████▌  | 1287/1375 [03:44<02:44,  1.86s/it]
# loglikelihood is using sigma_ as20.0
#  94%|████████████████████████████████████▌  | 1288/1375 [03:46<02:38,  1.82s/it]
# loglikelihood is using sigma_ as20.0
#  94%|████████████████████████████████████▋  | 1293/1375 [03:54<02:41,  1.97s/it]
# loglikelihood is using sigma_ as20.0
#  94%|████████████████████████████████████▊  | 1296/1375 [04:04<04:05,  3.10s/it]
# loglikelihood is using sigma_ as20.0
#  94%|████████████████████████████████████▊  | 1297/1375 [04:08<04:16,  3.28s/it]
# loglikelihood is using sigma_ as20.0
# loglikelihood is using sigma_ as20.0
#  95%|████████████████████████████████████▉  | 1301/1375 [04:16<02:33,  2.07s/it]
# loglikelihood is using sigma_ as20.0
#  95%|████████████████████████████████████▉  | 1304/1375 [04:20<01:58,  1.68s/it]
# loglikelihood is using sigma_ as20.0
# loglikelihood is using sigma_ as20.0
#  96%|█████████████████████████████████████▎ | 1315/1375 [04:37<00:54,  1.11it/s]
# loglikelihood is using sigma_ as20.0
#  96%|█████████████████████████████████████▎ | 1317/1375 [04:49<03:35,  3.72s/it]
# loglikelihood is using sigma_ as20.0
# loglikelihood is using sigma_ as20.0
#  96%|█████████████████████████████████████▍ | 1318/1375 [04:52<03:19,  3.50s/it]
# loglikelihood is using sigma_ as20.0
# loglikelihood is using sigma_ as20.0
#  96%|█████████████████████████████████████▍ | 1319/1375 [04:55<03:05,  3.31s/it]
# loglikelihood is using sigma_ as20.0
#  97%|█████████████████████████████████████▋ | 1327/1375 [05:23<02:36,  3.26s/it]
# loglikelihood is using sigma_ as20.0
#  97%|█████████████████████████████████████▊ | 1334/1375 [05:39<00:58,  1.44s/it]
# loglikelihood is using sigma_ as20.0
#  97%|█████████████████████████████████████▉ | 1337/1375 [05:43<00:52,  1.39s/it]
# loglikelihood is using sigma_ as20.0
#  97%|█████████████████████████████████████▉ | 1338/1375 [05:46<01:00,  1.65s/it]
# loglikelihood is using sigma_ as20.0
#  97%|█████████████████████████████████████▉ | 1339/1375 [05:46<00:46,  1.30s/it]
# loglikelihood is using sigma_ as20.0
#  97%|██████████████████████████████████████ | 1340/1375 [05:49<01:04,  1.84s/it]
# loglikelihood is using sigma_ as20.0
#  98%|██████████████████████████████████████ | 1342/1375 [05:54<01:07,  2.05s/it]
# loglikelihood is using sigma_ as20.0
#  98%|██████████████████████████████████████▏| 1345/1375 [06:05<01:26,  2.89s/it]
# loglikelihood is using sigma_ as20.0
#  98%|██████████████████████████████████████▏| 1346/1375 [06:05<01:03,  2.20s/it]
# loglikelihood is using sigma_ as20.0
#  98%|██████████████████████████████████████▏| 1347/1375 [06:06<00:47,  1.70s/it]
# loglikelihood is using sigma_ as20.0
# loglikelihood is using sigma_ as20.0
#  98%|██████████████████████████████████████▎| 1349/1375 [06:15<01:24,  3.24s/it]
# loglikelihood is using sigma_ as20.0
#  98%|██████████████████████████████████████▎| 1351/1375 [06:25<01:36,  4.04s/it]
# loglikelihood is using sigma_ as20.0
#  98%|██████████████████████████████████████▍| 1353/1375 [06:31<01:13,  3.34s/it]
# loglikelihood is using sigma_ as20.0
#  99%|██████████████████████████████████████▍| 1355/1375 [06:33<00:44,  2.24s/it]
# loglikelihood is using sigma_ as20.0
# loglikelihood is using sigma_ as20.0
#  99%|██████████████████████████████████████▍| 1356/1375 [06:37<00:48,  2.55s/it]
# loglikelihood is using sigma_ as20.0
#  99%|██████████████████████████████████████▌| 1360/1375 [06:44<00:28,  1.88s/it]
# loglikelihood is using sigma_ as20.0
#  99%|██████████████████████████████████████▌| 1361/1375 [06:50<00:46,  3.36s/it]
# loglikelihood is using sigma_ as20.0
#  99%|██████████████████████████████████████▋| 1364/1375 [07:01<00:31,  2.90s/it]
# loglikelihood is using sigma_ as20.0
#  99%|██████████████████████████████████████▊| 1368/1375 [07:13<00:17,  2.46s/it]
# loglikelihood is using sigma_ as20.0
# loglikelihood is using sigma_ as20.0
# loglikelihood is using sigma_ as20.0
# 100%|██████████████████████████████████████▊| 1370/1375 [07:26<00:19,  3.84s/it]
# loglikelihood is using sigma_ as20.0
# loglikelihood is using sigma_ as20.0
# 100%|██████████████████████████████████████▉| 1371/1375 [07:31<00:16,  4.23s/it]
# loglikelihood is using sigma_ as20.0
# loglikelihood is using sigma_ as20.0
# loglikelihood is using sigma_ as20.0
# 100%|██████████████████████████████████████▉| 1374/1375 [07:42<00:03,  3.29s/it]
# loglikelihood is using sigma_ as20.0
# 100%|███████████████████████████████████████| 1375/1375 [07:47<00:00,  2.94it/s]
# 9593.048845113006should be same as17.093676133295972
# tolerance chosen as1e-35
#  35%|█████████████▍                         | 475/1375 [00:00<00:02, 395.61it/s]
# loglikelihood is using sigma_ as100.0
# loglikelihood is using sigma_ as100.0
#  58%|███████████████████████                 | 793/1375 [00:04<00:11, 51.86it/s]
# loglikelihood is using sigma_ as100.0
#  62%|████████████████████████▊               | 851/1375 [00:06<00:20, 25.19it/s]
# loglikelihood is using sigma_ as100.0
#  71%|████████████████████████████▎           | 974/1375 [00:14<00:33, 12.09it/s]
# loglikelihood is using sigma_ as100.0
#  73%|████████████████████████████▎          | 1000/1375 [00:16<00:38,  9.64it/s]
# loglikelihood is using sigma_ as100.0
#  76%|█████████████████████████████▋         | 1047/1375 [00:22<00:44,  7.34it/s]
# loglikelihood is using sigma_ as100.0
#  81%|███████████████████████████████▋       | 1118/1375 [00:37<01:26,  2.96it/s]
# loglikelihood is using sigma_ as100.0
#  84%|████████████████████████████████▊      | 1158/1375 [00:49<01:19,  2.74it/s]
# loglikelihood is using sigma_ as100.0
#  84%|████████████████████████████████▉      | 1160/1375 [00:50<01:22,  2.62it/s]
# loglikelihood is using sigma_ as100.0
#  85%|█████████████████████████████████▎     | 1175/1375 [00:56<01:05,  3.05it/s]
# loglikelihood is using sigma_ as100.0
#  88%|██████████████████████████████████▏    | 1205/1375 [01:11<02:07,  1.33it/s]
# loglikelihood is using sigma_ as100.0
#  88%|██████████████████████████████████▏    | 1207/1375 [01:12<01:52,  1.49it/s]
# loglikelihood is using sigma_ as100.0
#  89%|██████████████████████████████████▌    | 1217/1375 [01:20<02:18,  1.14it/s]
# loglikelihood is using sigma_ as100.0
#  89%|██████████████████████████████████▋    | 1222/1375 [01:30<03:52,  1.52s/it]
# loglikelihood is using sigma_ as100.0
#  89%|██████████████████████████████████▊    | 1227/1375 [01:35<02:22,  1.04it/s]
# loglikelihood is using sigma_ as100.0
#  89%|██████████████████████████████████▊    | 1229/1375 [01:36<01:55,  1.26it/s]
# loglikelihood is using sigma_ as100.0
#  89%|██████████████████████████████████▉    | 1230/1375 [01:38<02:32,  1.05s/it]
# loglikelihood is using sigma_ as100.0
#  90%|███████████████████████████████████    | 1234/1375 [01:43<02:18,  1.02it/s]
# loglikelihood is using sigma_ as100.0
#  91%|███████████████████████████████████▍   | 1251/1375 [02:01<02:28,  1.20s/it]
# loglikelihood is using sigma_ as100.0
#  92%|███████████████████████████████████▋   | 1260/1375 [02:10<01:25,  1.35it/s]
# loglikelihood is using sigma_ as100.0
#  92%|███████████████████████████████████▊   | 1262/1375 [02:12<01:28,  1.27it/s]
# loglikelihood is using sigma_ as100.0
#  92%|███████████████████████████████████▊   | 1263/1375 [02:13<01:32,  1.20it/s]
# loglikelihood is using sigma_ as100.0
#  92%|███████████████████████████████████▊   | 1264/1375 [02:15<02:05,  1.13s/it]
# loglikelihood is using sigma_ as100.0
#  92%|███████████████████████████████████▉   | 1265/1375 [02:16<02:20,  1.27s/it]
# loglikelihood is using sigma_ as100.0
#  93%|████████████████████████████████████   | 1273/1375 [02:23<01:30,  1.13it/s]
# loglikelihood is using sigma_ as100.0
#  93%|████████████████████████████████████▏  | 1277/1375 [02:26<01:17,  1.27it/s]
# loglikelihood is using sigma_ as100.0
#  93%|████████████████████████████████████▎  | 1282/1375 [02:35<01:47,  1.16s/it]
# loglikelihood is using sigma_ as100.0
#  93%|████████████████████████████████████▍  | 1283/1375 [02:36<01:44,  1.14s/it]
# loglikelihood is using sigma_ as100.0
#  93%|████████████████████████████████████▍  | 1284/1375 [02:37<01:35,  1.05s/it]
# loglikelihood is using sigma_ as100.0
#  93%|████████████████████████████████████▍  | 1285/1375 [02:39<02:15,  1.50s/it]
# loglikelihood is using sigma_ as100.0
#  95%|████████████████████████████████████▉  | 1301/1375 [02:56<00:46,  1.58it/s]
# loglikelihood is using sigma_ as100.0
#  95%|█████████████████████████████████████  | 1306/1375 [03:00<00:55,  1.25it/s]
# loglikelihood is using sigma_ as100.0
#  95%|█████████████████████████████████████▏ | 1312/1375 [03:09<01:40,  1.60s/it]
# loglikelihood is using sigma_ as100.0
#  96%|█████████████████████████████████████▍ | 1318/1375 [03:16<01:13,  1.29s/it]
# loglikelihood is using sigma_ as100.0
#  96%|█████████████████████████████████████▍ | 1320/1375 [03:18<01:03,  1.15s/it]
# loglikelihood is using sigma_ as100.0
#  97%|█████████████████████████████████████▊ | 1332/1375 [03:33<00:44,  1.04s/it]
# loglikelihood is using sigma_ as100.0
# loglikelihood is using sigma_ as100.0
#  97%|█████████████████████████████████████▊ | 1333/1375 [03:40<02:03,  2.95s/it]
# loglikelihood is using sigma_ as100.0
#  97%|█████████████████████████████████████▉ | 1337/1375 [03:46<01:22,  2.17s/it]
# loglikelihood is using sigma_ as100.0
#  98%|██████████████████████████████████████ | 1344/1375 [04:05<01:20,  2.58s/it]
# loglikelihood is using sigma_ as100.0
#  98%|██████████████████████████████████████▏| 1346/1375 [04:12<01:20,  2.78s/it]
# loglikelihood is using sigma_ as100.0
#  98%|██████████████████████████████████████▎| 1350/1375 [04:28<01:12,  2.90s/it]
# loglikelihood is using sigma_ as100.0
#  99%|██████████████████████████████████████▌| 1361/1375 [04:48<00:28,  2.00s/it]
# loglikelihood is using sigma_ as100.0
#  99%|██████████████████████████████████████▋| 1363/1375 [04:56<00:40,  3.34s/it]
# loglikelihood is using sigma_ as100.0
#  99%|██████████████████████████████████████▋| 1366/1375 [05:05<00:23,  2.66s/it]
# loglikelihood is using sigma_ as100.0
#  99%|██████████████████████████████████████▊| 1367/1375 [05:06<00:16,  2.10s/it]
# loglikelihood is using sigma_ as100.0
# 100%|██████████████████████████████████████▉| 1374/1375 [05:22<00:01,  1.50s/it]
# loglikelihood is using sigma_ as100.0
# 100%|███████████████████████████████████████| 1375/1375 [05:24<00:00,  4.24it/s]
# 106723.2706050784should be same as94.98728211456718

# %%
sigma_ = 0
mh1= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0],[1,1]],ndims=2,tol=1e-30)

fig,axs=mh1.MCMC2d(parameters=['x0','x1'],label_='deterministic orthodox')

sigma_=1000.0

for sigma_ in [1000.0,10000.0]:    
    mh_err= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0], [1,1]], ndims=2,tol=1e-35)
    mh_err.MCMC2d(parameters=axs,label_='non-deterministic with std error='+str(sigma_))


handles, labels = axs['x0']['x0'].get_legend_handles_labels()
leg = fig.legend(handles, labels)
fig.tight_layout()
plt.show()


plt.figure(0)
# Out:
# tolerance chosen as1e-30
#  65%|██████████████████████████▏             | 900/1375 [00:11<00:33, 14.20it/s]
# loglikelihood is using sigma_ as0
#  72%|████████████████████████████▋           | 987/1375 [00:23<01:16,  5.08it/s]
# loglikelihood is using sigma_ as0
#  73%|████████████████████████████▌          | 1005/1375 [00:27<01:19,  4.64it/s]
# loglikelihood is using sigma_ as0
#  74%|████████████████████████████▋          | 1013/1375 [00:28<00:45,  7.98it/s]
# loglikelihood is using sigma_ as0
#  75%|█████████████████████████████▏         | 1027/1375 [00:31<01:22,  4.24it/s]
# loglikelihood is using sigma_ as0
#  81%|███████████████████████████████▌       | 1111/1375 [00:58<01:42,  2.59it/s]
# loglikelihood is using sigma_ as0
#  81%|███████████████████████████████▌       | 1113/1375 [00:59<02:10,  2.01it/s]
# loglikelihood is using sigma_ as0
#  82%|████████████████████████████████       | 1132/1375 [01:07<02:01,  1.99it/s]
# loglikelihood is using sigma_ as0
#  84%|████████████████████████████████▌      | 1149/1375 [01:14<01:23,  2.72it/s]
# loglikelihood is using sigma_ as0
#  84%|████████████████████████████████▋      | 1152/1375 [01:16<01:38,  2.27it/s]
# loglikelihood is using sigma_ as0
#  84%|████████████████████████████████▋      | 1154/1375 [01:17<01:47,  2.06it/s]
# loglikelihood is using sigma_ as0
#  85%|████████████████████████████████▉      | 1162/1375 [01:20<01:13,  2.89it/s]
# loglikelihood is using sigma_ as0
#  86%|█████████████████████████████████▋     | 1187/1375 [01:36<03:05,  1.01it/s]
# loglikelihood is using sigma_ as0
#  87%|█████████████████████████████████▉     | 1198/1375 [01:44<02:06,  1.40it/s]
# loglikelihood is using sigma_ as0
#  89%|██████████████████████████████████▌    | 1217/1375 [01:58<01:33,  1.69it/s]
# loglikelihood is using sigma_ as0
#  89%|██████████████████████████████████▊    | 1226/1375 [02:08<01:45,  1.41it/s]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  89%|██████████████████████████████████▉    | 1230/1375 [02:12<01:59,  1.21it/s]
# loglikelihood is using sigma_ as0
#  90%|██████████████████████████████████▉    | 1233/1375 [02:20<04:49,  2.04s/it]
# loglikelihood is using sigma_ as0
#  90%|███████████████████████████████████    | 1236/1375 [02:21<02:37,  1.13s/it]
# loglikelihood is using sigma_ as0
#  90%|███████████████████████████████████▏   | 1242/1375 [02:29<01:48,  1.23it/s]
# loglikelihood is using sigma_ as0
#  91%|███████████████████████████████████▌   | 1255/1375 [02:48<04:17,  2.15s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  92%|███████████████████████████████████▊   | 1261/1375 [02:56<02:15,  1.19s/it]
# loglikelihood is using sigma_ as0
#  92%|███████████████████████████████████▊   | 1264/1375 [02:59<01:57,  1.06s/it]
# loglikelihood is using sigma_ as0
#  92%|███████████████████████████████████▉   | 1265/1375 [03:03<03:22,  1.84s/it]
# loglikelihood is using sigma_ as0
#  94%|████████████████████████████████████▋  | 1293/1375 [03:41<02:19,  1.70s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  94%|████████████████████████████████████▊  | 1297/1375 [03:59<03:49,  2.94s/it]
# loglikelihood is using sigma_ as0
#  94%|████████████████████████████████████▊  | 1299/1375 [04:00<02:29,  1.97s/it]
# loglikelihood is using sigma_ as0
#  95%|████████████████████████████████████▊  | 1300/1375 [04:02<02:26,  1.95s/it]
# loglikelihood is using sigma_ as0
#  95%|█████████████████████████████████████  | 1305/1375 [04:05<01:20,  1.15s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  95%|█████████████████████████████████████▏ | 1309/1375 [04:13<01:25,  1.29s/it]
# loglikelihood is using sigma_ as0
#  95%|█████████████████████████████████████▏ | 1310/1375 [04:15<01:23,  1.28s/it]
# loglikelihood is using sigma_ as0
#  95%|█████████████████████████████████████▏ | 1313/1375 [04:18<01:06,  1.08s/it]
# loglikelihood is using sigma_ as0
#  96%|█████████████████████████████████████▍ | 1321/1375 [04:37<02:20,  2.60s/it]
# loglikelihood is using sigma_ as0
#  96%|█████████████████████████████████████▌ | 1323/1375 [04:44<02:19,  2.68s/it]
# loglikelihood is using sigma_ as0
#  97%|█████████████████████████████████████▋ | 1330/1375 [05:00<01:38,  2.18s/it]
# loglikelihood is using sigma_ as0
#  97%|█████████████████████████████████████▊ | 1332/1375 [05:05<01:40,  2.34s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  97%|█████████████████████████████████████▉ | 1338/1375 [05:14<00:48,  1.30s/it]
# loglikelihood is using sigma_ as0
#  98%|██████████████████████████████████████ | 1343/1375 [05:23<01:07,  2.10s/it]
# loglikelihood is using sigma_ as0
#  98%|██████████████████████████████████████▎| 1349/1375 [05:39<01:00,  2.34s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  98%|██████████████████████████████████████▎| 1350/1375 [05:42<01:07,  2.68s/it]
# loglikelihood is using sigma_ as0
#  98%|██████████████████████████████████████▍| 1353/1375 [05:50<00:50,  2.31s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  98%|██████████████████████████████████████▍| 1354/1375 [06:03<01:44,  4.96s/it]
# loglikelihood is using sigma_ as0
#  99%|██████████████████████████████████████▍| 1355/1375 [06:05<01:26,  4.32s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  99%|██████████████████████████████████████▌| 1360/1375 [06:15<00:31,  2.08s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  99%|██████████████████████████████████████▌| 1361/1375 [06:36<01:47,  7.65s/it]
# loglikelihood is using sigma_ as0
#  99%|██████████████████████████████████████▋| 1363/1375 [06:39<00:54,  4.51s/it]
# loglikelihood is using sigma_ as0
#  99%|██████████████████████████████████████▋| 1364/1375 [06:43<00:47,  4.34s/it]
# loglikelihood is using sigma_ as0
#  99%|██████████████████████████████████████▊| 1367/1375 [06:50<00:24,  3.07s/it]
# loglikelihood is using sigma_ as0
#  99%|██████████████████████████████████████▊| 1368/1375 [06:53<00:21,  3.07s/it]
# loglikelihood is using sigma_ as0
# 100%|██████████████████████████████████████▉| 1371/1375 [07:08<00:14,  3.52s/it]
# loglikelihood is using sigma_ as0
# 100%|███████████████████████████████████████| 1375/1375 [07:14<00:00,  3.17it/s]
# -13226.237972083783should be same as-0.08828344967573987
# tolerance chosen as1e-35
#   9%|███▍                                   | 121/1375 [00:00<00:02, 601.34it/s]/Users/sahibzadaallahyar/Documents/codes/GitHub/clean/nestedsampling/samplers.py:75: RuntimeWarning: overflow encountered in exp
#   self.frac= np.log(0.5*(np.exp(self.logL[-1])+np.exp(self.logL[-2]))*(np.exp(self.logX[-2])-np.exp(self.logX[-1])))
# /Users/sahibzadaallahyar/Documents/codes/GitHub/clean/nestedsampling/samplers.py:87: RuntimeWarning: overflow encountered in exp
#   self.frac= np.log(0.5*(np.exp(self.logL[-1])+np.exp(self.logL[-2]))*(np.exp(self.logX[-2])-np.exp(self.logX[-1])))
#  55%|█████████████████████▉                  | 755/1375 [00:05<00:15, 40.40it/s]
# loglikelihood is using sigma_ as1000.0
#  61%|████████████████████████▍               | 839/1375 [00:09<00:44, 11.91it/s]
# loglikelihood is using sigma_ as1000.0
#  73%|████████████████████████████▍          | 1002/1375 [00:33<02:45,  2.25it/s]
# loglikelihood is using sigma_ as1000.0
#  74%|████████████████████████████▊          | 1016/1375 [00:37<01:29,  4.01it/s]
# loglikelihood is using sigma_ as1000.0
#  78%|██████████████████████████████▍        | 1073/1375 [01:03<02:28,  2.04it/s]
# loglikelihood is using sigma_ as1000.0
#  80%|███████████████████████████████▏       | 1100/1375 [01:20<02:23,  1.91it/s]
# loglikelihood is using sigma_ as1000.0
#  81%|███████████████████████████████▌       | 1114/1375 [01:26<02:20,  1.86it/s]
# loglikelihood is using sigma_ as1000.0
#  82%|███████████████████████████████▉       | 1126/1375 [01:32<01:43,  2.40it/s]
# loglikelihood is using sigma_ as1000.0
#  84%|████████████████████████████████▌      | 1149/1375 [01:54<04:41,  1.25s/it]
# loglikelihood is using sigma_ as1000.0
#  84%|████████████████████████████████▋      | 1154/1375 [02:04<06:24,  1.74s/it]
# loglikelihood is using sigma_ as1000.0
#  85%|█████████████████████████████████      | 1167/1375 [02:15<02:13,  1.56it/s]
# loglikelihood is using sigma_ as1000.0
#  85%|█████████████████████████████████▎     | 1174/1375 [02:26<05:10,  1.55s/it]
# loglikelihood is using sigma_ as1000.0
#  86%|█████████████████████████████████▍     | 1177/1375 [02:28<03:31,  1.07s/it]
# loglikelihood is using sigma_ as1000.0
#  86%|█████████████████████████████████▋     | 1188/1375 [02:42<03:59,  1.28s/it]
# loglikelihood is using sigma_ as1000.0
#  87%|█████████████████████████████████▊     | 1192/1375 [02:44<02:00,  1.51it/s]
# loglikelihood is using sigma_ as1000.0
#  88%|██████████████████████████████████▏    | 1205/1375 [02:56<02:34,  1.10it/s]
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
#  88%|██████████████████████████████████▎    | 1208/1375 [03:02<04:02,  1.45s/it]
# loglikelihood is using sigma_ as1000.0
#  88%|██████████████████████████████████▍    | 1212/1375 [03:05<02:15,  1.21it/s]
# loglikelihood is using sigma_ as1000.0
#  88%|██████████████████████████████████▍    | 1216/1375 [03:09<02:07,  1.25it/s]
# loglikelihood is using sigma_ as1000.0
#  89%|██████████████████████████████████▊    | 1228/1375 [03:20<03:04,  1.26s/it]
# loglikelihood is using sigma_ as1000.0
#  89%|██████████████████████████████████▊    | 1229/1375 [03:27<07:14,  2.98s/it]
# loglikelihood is using sigma_ as1000.0
#  90%|███████████████████████████████████    | 1235/1375 [03:38<04:41,  2.01s/it]
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
#  90%|███████████████████████████████████    | 1236/1375 [03:47<09:18,  4.02s/it]
# loglikelihood is using sigma_ as1000.0
#  90%|███████████████████████████████████    | 1237/1375 [03:51<09:41,  4.22s/it]
# loglikelihood is using sigma_ as1000.0
#  90%|███████████████████████████████████    | 1238/1375 [03:54<08:36,  3.77s/it]
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
#  90%|███████████████████████████████████▏   | 1241/1375 [04:02<05:59,  2.68s/it]
# loglikelihood is using sigma_ as1000.0
#  90%|███████████████████████████████████▎   | 1244/1375 [04:08<05:12,  2.39s/it]
# loglikelihood is using sigma_ as1000.0
#  91%|███████████████████████████████████▎   | 1247/1375 [04:12<03:04,  1.44s/it]
# loglikelihood is using sigma_ as1000.0
#  91%|███████████████████████████████████▍   | 1249/1375 [04:16<03:31,  1.68s/it]
# loglikelihood is using sigma_ as1000.0
#  92%|███████████████████████████████████▉   | 1269/1375 [04:58<02:38,  1.50s/it]
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
#  93%|████████████████████████████████████▏  | 1274/1375 [05:14<05:04,  3.01s/it]
# loglikelihood is using sigma_ as1000.0
#  93%|████████████████████████████████████▏  | 1275/1375 [05:20<06:40,  4.01s/it]
# loglikelihood is using sigma_ as1000.0
#  93%|████████████████████████████████████▏  | 1277/1375 [05:23<04:30,  2.77s/it]
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
#  93%|████████████████████████████████████▎  | 1282/1375 [05:43<05:35,  3.61s/it]
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
#  93%|████████████████████████████████████▍  | 1284/1375 [05:48<04:25,  2.91s/it]
# loglikelihood is using sigma_ as1000.0
#  94%|████████████████████████████████████▍  | 1286/1375 [05:53<03:58,  2.68s/it]
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
#  94%|████████████████████████████████████▌  | 1287/1375 [05:57<04:50,  3.30s/it]
# loglikelihood is using sigma_ as1000.0
#  94%|████████████████████████████████████▌  | 1289/1375 [06:03<04:12,  2.94s/it]
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
#  94%|████████████████████████████████████▌  | 1290/1375 [06:04<03:40,  2.59s/it]
# loglikelihood is using sigma_ as1000.0
#  94%|████████████████████████████████████▌  | 1291/1375 [06:06<03:24,  2.44s/it]
# loglikelihood is using sigma_ as1000.0
#  94%|████████████████████████████████████▋  | 1294/1375 [06:16<03:11,  2.36s/it]
# loglikelihood is using sigma_ as1000.0
#  94%|████████████████████████████████████▊  | 1296/1375 [06:23<03:51,  2.93s/it]
# loglikelihood is using sigma_ as1000.0
#  94%|████████████████████████████████████▊  | 1297/1375 [06:28<04:59,  3.84s/it]
# loglikelihood is using sigma_ as1000.0
#  95%|████████████████████████████████████▉  | 1304/1375 [06:43<01:36,  1.36s/it]
# loglikelihood is using sigma_ as1000.0
#  95%|█████████████████████████████████████  | 1305/1375 [06:47<02:32,  2.18s/it]
# loglikelihood is using sigma_ as1000.0
#  95%|█████████████████████████████████████  | 1307/1375 [06:55<03:16,  2.90s/it]
# loglikelihood is using sigma_ as1000.0
#  95%|█████████████████████████████████████  | 1308/1375 [07:06<06:02,  5.41s/it]
# loglikelihood is using sigma_ as1000.0
#  96%|█████████████████████████████████████▎ | 1314/1375 [07:19<02:21,  2.31s/it]
# loglikelihood is using sigma_ as1000.0
#  96%|█████████████████████████████████████▎ | 1315/1375 [07:19<01:45,  1.75s/it]
# loglikelihood is using sigma_ as1000.0
#  96%|█████████████████████████████████████▌ | 1323/1375 [07:34<01:25,  1.65s/it]
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
#  96%|█████████████████████████████████████▌ | 1324/1375 [07:40<02:26,  2.86s/it]
# loglikelihood is using sigma_ as1000.0
#  97%|█████████████████████████████████████▋ | 1329/1375 [07:59<02:58,  3.89s/it]
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
#  97%|█████████████████████████████████████▊ | 1333/1375 [08:14<02:18,  3.29s/it]
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
#  97%|█████████████████████████████████████▊ | 1335/1375 [08:20<02:02,  3.06s/it]
# loglikelihood is using sigma_ as1000.0
#  97%|█████████████████████████████████████▉ | 1339/1375 [08:29<01:19,  2.21s/it]
# loglikelihood is using sigma_ as1000.0
#  98%|██████████████████████████████████████ | 1344/1375 [08:41<00:58,  1.89s/it]
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
#  98%|██████████████████████████████████████▏| 1345/1375 [08:49<01:48,  3.61s/it]
# loglikelihood is using sigma_ as1000.0
#  98%|██████████████████████████████████████▏| 1348/1375 [08:58<01:21,  3.03s/it]
# loglikelihood is using sigma_ as1000.0
#  98%|██████████████████████████████████████▍| 1353/1375 [09:05<00:34,  1.56s/it]
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
#  98%|██████████████████████████████████████▍| 1354/1375 [09:12<00:59,  2.83s/it]
# loglikelihood is using sigma_ as1000.0
#  99%|██████████████████████████████████████▌| 1358/1375 [09:19<00:34,  2.05s/it]
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
#  99%|██████████████████████████████████████▌| 1361/1375 [09:32<00:42,  3.07s/it]
# loglikelihood is using sigma_ as1000.0
#  99%|██████████████████████████████████████▋| 1362/1375 [09:43<01:11,  5.53s/it]
# loglikelihood is using sigma_ as1000.0
#  99%|██████████████████████████████████████▋| 1365/1375 [09:52<00:36,  3.65s/it]
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
# loglikelihood is using sigma_ as1000.0
#  99%|██████████████████████████████████████▋| 1366/1375 [10:04<00:55,  6.13s/it]
# loglikelihood is using sigma_ as1000.0
#  99%|██████████████████████████████████████▊| 1368/1375 [10:08<00:28,  4.06s/it]
# loglikelihood is using sigma_ as1000.0
# 100%|██████████████████████████████████████▉| 1371/1375 [10:23<00:16,  4.12s/it]
# loglikelihood is using sigma_ as1000.0
# 100%|██████████████████████████████████████▉| 1373/1375 [10:31<00:08,  4.03s/it]
# loglikelihood is using sigma_ as1000.0
# 100%|███████████████████████████████████████| 1375/1375 [10:34<00:00,  2.17it/s]
# infshould be same as993.3380337082652
# tolerance chosen as1e-35
#   0%|                                                  | 0/1375 [00:00<?, ?it/s]/Users/sahibzadaallahyar/Documents/codes/GitHub/clean/nestedsampling/samplers.py:75: RuntimeWarning: overflow encountered in exp
#   self.frac= np.log(0.5*(np.exp(self.logL[-1])+np.exp(self.logL[-2]))*(np.exp(self.logX[-2])-np.exp(self.logX[-1])))
# /Users/sahibzadaallahyar/Documents/codes/GitHub/clean/nestedsampling/samplers.py:87: RuntimeWarning: overflow encountered in exp
#   self.frac= np.log(0.5*(np.exp(self.logL[-1])+np.exp(self.logL[-2]))*(np.exp(self.logX[-2])-np.exp(self.logX[-1])))
#  51%|████████████████████▎                   | 697/1375 [00:03<00:08, 81.80it/s]
# loglikelihood is using sigma_ as10000.0
#  68%|███████████████████████████             | 930/1375 [00:16<00:53,  8.27it/s]
# loglikelihood is using sigma_ as10000.0
#  73%|████████████████████████████▍          | 1004/1375 [00:27<00:38,  9.71it/s]
# loglikelihood is using sigma_ as10000.0
#  75%|█████████████████████████████▍         | 1038/1375 [00:36<01:51,  3.02it/s]
# loglikelihood is using sigma_ as10000.0
#  76%|█████████████████████████████▊         | 1049/1375 [00:40<01:34,  3.45it/s]
# loglikelihood is using sigma_ as10000.0
#  78%|██████████████████████████████▌        | 1079/1375 [00:51<01:05,  4.50it/s]
# loglikelihood is using sigma_ as10000.0
#  80%|███████████████████████████████        | 1094/1375 [00:59<02:52,  1.63it/s]
# loglikelihood is using sigma_ as10000.0
#  80%|███████████████████████████████▏       | 1099/1375 [01:03<03:11,  1.44it/s]
# loglikelihood is using sigma_ as10000.0
#  80%|███████████████████████████████▎       | 1106/1375 [01:06<01:19,  3.37it/s]
# loglikelihood is using sigma_ as10000.0
#  82%|████████████████████████████████       | 1130/1375 [01:18<03:15,  1.25it/s]
# loglikelihood is using sigma_ as10000.0
#  83%|████████████████████████████████▍      | 1144/1375 [01:27<02:10,  1.77it/s]
# loglikelihood is using sigma_ as10000.0
#  83%|████████████████████████████████▌      | 1148/1375 [01:30<02:56,  1.29it/s]
# loglikelihood is using sigma_ as10000.0
#  85%|████████████████████████████████▉      | 1163/1375 [01:42<02:33,  1.38it/s]
# loglikelihood is using sigma_ as10000.0
#  86%|█████████████████████████████████▍     | 1180/1375 [02:03<05:19,  1.64s/it]
# loglikelihood is using sigma_ as10000.0
#  87%|██████████████████████████████████     | 1202/1375 [02:26<02:35,  1.12it/s]
# loglikelihood is using sigma_ as10000.0
#  88%|██████████████████████████████████▏    | 1204/1375 [02:30<03:43,  1.31s/it]
# loglikelihood is using sigma_ as10000.0
#  88%|██████████████████████████████████▍    | 1213/1375 [02:40<02:17,  1.18it/s]
# loglikelihood is using sigma_ as10000.0
#  89%|██████████████████████████████████▌    | 1217/1375 [02:53<07:17,  2.77s/it]
# loglikelihood is using sigma_ as10000.0
#  89%|██████████████████████████████████▋    | 1224/1375 [02:59<02:17,  1.10it/s]
# loglikelihood is using sigma_ as10000.0
#  89%|██████████████████████████████████▊    | 1227/1375 [03:04<03:11,  1.29s/it]
# loglikelihood is using sigma_ as10000.0
#  89%|██████████████████████████████████▊    | 1228/1375 [03:07<04:16,  1.74s/it]
# loglikelihood is using sigma_ as10000.0
#  89%|██████████████████████████████████▉    | 1230/1375 [03:08<03:01,  1.25s/it]
# loglikelihood is using sigma_ as10000.0
#  91%|███████████████████████████████████▎   | 1245/1375 [03:29<04:41,  2.16s/it]
# loglikelihood is using sigma_ as10000.0
#  92%|████████████████████████████████████   | 1270/1375 [04:08<02:37,  1.50s/it]
# loglikelihood is using sigma_ as10000.0
#  93%|████████████████████████████████████   | 1273/1375 [04:17<03:45,  2.21s/it]
# loglikelihood is using sigma_ as10000.0
#  93%|████████████████████████████████████▏  | 1277/1375 [04:22<02:32,  1.55s/it]
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
#  93%|████████████████████████████████████▎  | 1279/1375 [04:33<05:15,  3.29s/it]
# loglikelihood is using sigma_ as10000.0
#  93%|████████████████████████████████████▎  | 1280/1375 [04:37<05:43,  3.61s/it]
# loglikelihood is using sigma_ as10000.0
#  93%|████████████████████████████████████▎  | 1282/1375 [04:40<03:34,  2.30s/it]
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
#  93%|████████████████████████████████████▍  | 1285/1375 [04:45<02:46,  1.85s/it]
# loglikelihood is using sigma_ as10000.0
#  94%|████████████████████████████████████▌  | 1288/1375 [04:58<05:42,  3.93s/it]
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
#  94%|████████████████████████████████████▌  | 1290/1375 [05:02<03:55,  2.77s/it]
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
#  94%|████████████████████████████████████▋  | 1295/1375 [05:22<03:27,  2.60s/it]
# loglikelihood is using sigma_ as10000.0
#  94%|████████████████████████████████████▊  | 1299/1375 [05:34<03:49,  3.02s/it]
# loglikelihood is using sigma_ as10000.0
#  95%|████████████████████████████████████▉  | 1303/1375 [05:43<02:45,  2.30s/it]
# loglikelihood is using sigma_ as10000.0
#  95%|████████████████████████████████████▉  | 1304/1375 [05:45<02:38,  2.23s/it]
# loglikelihood is using sigma_ as10000.0
#  95%|█████████████████████████████████████  | 1308/1375 [05:56<02:33,  2.29s/it]
# loglikelihood is using sigma_ as10000.0
#  95%|█████████████████████████████████████▏ | 1309/1375 [06:00<02:52,  2.62s/it]
# loglikelihood is using sigma_ as10000.0
#  95%|█████████████████████████████████████▏ | 1310/1375 [06:03<02:58,  2.75s/it]
# loglikelihood is using sigma_ as10000.0
#  95%|█████████████████████████████████████▏ | 1313/1375 [06:07<01:53,  1.83s/it]
# loglikelihood is using sigma_ as10000.0
#  96%|█████████████████████████████████████▎ | 1315/1375 [06:12<01:57,  1.96s/it]
# loglikelihood is using sigma_ as10000.0
#  96%|█████████████████████████████████████▍ | 1320/1375 [06:23<02:02,  2.23s/it]
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
#  96%|█████████████████████████████████████▍ | 1322/1375 [06:29<02:09,  2.45s/it]
# loglikelihood is using sigma_ as10000.0
#  96%|█████████████████████████████████████▌ | 1325/1375 [06:36<02:11,  2.64s/it]
# loglikelihood is using sigma_ as10000.0
#  96%|█████████████████████████████████████▌ | 1326/1375 [06:37<01:51,  2.28s/it]
# loglikelihood is using sigma_ as10000.0
#  97%|█████████████████████████████████████▋ | 1327/1375 [06:44<02:54,  3.63s/it]
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
#  97%|█████████████████████████████████████▋ | 1328/1375 [06:50<03:25,  4.37s/it]
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
#  97%|█████████████████████████████████████▊ | 1332/1375 [07:04<02:22,  3.31s/it]
# loglikelihood is using sigma_ as10000.0
#  97%|█████████████████████████████████████▉ | 1339/1375 [07:24<01:50,  3.07s/it]
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
#  98%|██████████████████████████████████████▏| 1345/1375 [07:51<01:37,  3.24s/it]
# loglikelihood is using sigma_ as10000.0
#  98%|██████████████████████████████████████▏| 1346/1375 [08:03<02:49,  5.84s/it]
# loglikelihood is using sigma_ as10000.0
#  98%|██████████████████████████████████████▏| 1348/1375 [08:13<02:14,  4.99s/it]
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
#  98%|██████████████████████████████████████▎| 1350/1375 [08:23<02:02,  4.89s/it]
# loglikelihood is using sigma_ as10000.0
#  98%|██████████████████████████████████████▍| 1353/1375 [08:29<01:09,  3.14s/it]
# loglikelihood is using sigma_ as10000.0
#  99%|██████████████████████████████████████▍| 1356/1375 [08:36<00:45,  2.39s/it]
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
#  99%|██████████████████████████████████████▍| 1357/1375 [08:43<01:07,  3.73s/it]
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
#  99%|██████████████████████████████████████▌| 1358/1375 [08:53<01:31,  5.40s/it]
# loglikelihood is using sigma_ as10000.0
#  99%|██████████████████████████████████████▌| 1360/1375 [09:02<01:12,  4.80s/it]
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
#  99%|██████████████████████████████████████▋| 1362/1375 [09:10<00:54,  4.20s/it]
# loglikelihood is using sigma_ as10000.0
#  99%|██████████████████████████████████████▋| 1364/1375 [09:18<00:42,  3.85s/it]
# loglikelihood is using sigma_ as10000.0
#  99%|██████████████████████████████████████▋| 1366/1375 [09:23<00:27,  3.05s/it]
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
# 100%|██████████████████████████████████████▊| 1369/1375 [09:29<00:13,  2.27s/it]
# loglikelihood is using sigma_ as10000.0
# 100%|██████████████████████████████████████▊| 1370/1375 [09:31<00:09,  1.95s/it]
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
# 100%|██████████████████████████████████████▉| 1371/1375 [09:38<00:14,  3.61s/it]
# loglikelihood is using sigma_ as10000.0
# loglikelihood is using sigma_ as10000.0
# 100%|██████████████████████████████████████▉| 1372/1375 [09:41<00:09,  3.33s/it]
# loglikelihood is using sigma_ as10000.0
# 100%|███████████████████████████████████████| 1375/1375 [09:50<00:00,  2.33it/s]
# infshould be same as9990.041085653484
