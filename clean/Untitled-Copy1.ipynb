# %%
from nestedsampling.samplers import NSrun
import numpy as np
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
import sys
import pandas as pd

def loglikelihood(x):
    mean = np.array([0.5, 0.5])
    cov = np.array([[0.01, 0.0], [0.0, 0.01 ]])
    logL = multivariate_normal.logpdf(x, mean=mean, cov=cov) + np.random.normal(0,sigma_)
    prob = np.random.rand()
    if prob>0.99999: 
        print('loglikelihood is using sigma_ as'+str(sigma_))
    return logL


def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))/(sig*np.sqrt(2*np.pi))


# sigma_ = 0
# mh1= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0],[1,1]],ndims=2,tol=1e-30)

# fig,axs=mh1.MCMC2d(parameters=['x0','x1'],label_='deterministic orthodox')

# sigma_=0.25

# for sigma_ in [0.25,20.0,100.0]:    
#     mh_err= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0], [1,1]], ndims=2,tol=1e-35)
#     mh_err.MCMC2d(parameters=axs,label_='non-deterministic with std error='+str(sigma_))


# handles, labels = axs['x0']['x0'].get_legend_handles_labels()
# leg = fig.legend(handles, labels)
# fig.tight_layout()
# plt.show()


# plt.figure(0)
# x = np.linspace(0,1,3000)
  
# mean = 0.5, 
# sigg = 0.1
# y = gaussian(x, mu=mean, sig=sigg)



# axs['x0']['x0'].plot(x,y,label= 'gaussian')

# axs['x1']['x1'].plot(x,y,label= 'gaussian')


# handles, labels = axs['x0']['x1'].get_legend_handles_labels()
# leg = fig.legend(handles, labels)
# fig.tight_layout()
# plt.show()

# sys.exit(0)

#####################################################
'''%Metropolis hastings below'''


sigma_ = 0.0
mh= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0],[1,1]],ndims=2,Metropolis=True)

fig,axs=mh.MCMC2d(parameters=['x0','x1'],label_='deterministic Metropolis')

for sigma_ in [0.25,20.0,100.0]:    
    mh2= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0], [1,1]], ndims=2,Metropolis=True)
    mh2.MCMC2d(parameters=axs,label_='non-deterministic Metropolis with std error='+str(sigma_))
# with std error='+str(sigma_))


# x = np.linspace(0,1,3000)

# mean = 0.5, 
# sigg = 0.1
# y = gaussian(x, mu=mean, sig=sigg)

# axs['x0']['x0'].plot(x,y,color='purple')
    


# axs['x1']['x1'].plot(x,y,color='purple')
    


handles, labels = axs['x0']['x0'].get_legend_handles_labels()
leg = fig.legend(handles, labels)
fig.tight_layout()
plt.show()


plt.figure(0)

# plt.hist(mh1.logZ_int(200),label= 'ORTHODOX', alpha=0.5)
# plt.hist(mh2.logZ_int(200),label= 'MCMC',alpha=0.5)

# plt.legend(loc="upper left")








# # df = pd.DataFrame({
# #     'x_vals':x_
# # })
# # df['Actual Gaussian']=y

# # df.plot(x=x_,y='Actual Gaussian',ax=axs['x0']['x0'],color='purple')

# # df.plot(x=x_,y='Actual Gaussian',ax=axs['x1']['x1'],color='purple')
# Out:
# tolerance chosen as1e-30
# 100%|██████████████████████████████████████| 1375/1375 [00:05<00:00, 257.15it/s]
# random walk steps are12
# -13078.221841075276should be same as0.007694836481842771
# tolerance chosen as1e-30
#  86%|████████████████████████████████▋     | 1183/1375 [00:06<00:01, 120.16it/s]
# loglikelihood is using sigma_ as0.25
# 100%|██████████████████████████████████████| 1375/1375 [00:08<00:00, 160.50it/s]
# random walk steps are12
# -13137.031744595157should be same as0.15907653295117052
# tolerance chosen as1e-30
# 100%|██████████████████████████████████████| 1375/1375 [00:10<00:00, 132.66it/s]
# random walk steps are12
# -13072.687685397828should be same as13.685087203445953
# tolerance chosen as1e-30
# 100%|██████████████████████████████████████| 1375/1375 [00:10<00:00, 135.48it/s]
# random walk steps are12
# 16190.565908723029should be same as118.55563434205284

# %%
from nestedsampling.samplers import NSrun
import numpy as np
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
import sys
import pandas as pd

def loglikelihood(x):
    mean = np.array([0.5, 0.5])
    cov = np.array([[0.01, 0.0], [0.0, 0.01 ]])
    logL = multivariate_normal.logpdf(x, mean=mean, cov=cov) + np.random.normal(0,sigma_)
    prob = np.random.rand()
    if prob>0.99999: 
        print('loglikelihood is using sigma_ as'+str(sigma_))
    return logL


def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))/(sig*np.sqrt(2*np.pi))

# %%
from nestedsampling.samplers import NSrun
import numpy as np
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
import sys
import pandas as pd

def loglikelihood(x):
    mean = np.array([0.5, 0.5])
    cov = np.array([[0.01, 0.0], [0.0, 0.01 ]])
    logL = multivariate_normal.logpdf(x, mean=mean, cov=cov) + np.random.normal(0,sigma_)
    prob = np.random.rand()
    if prob>0.99999: 
        print('loglikelihood is using sigma_ as'+str(sigma_))
    return logL


def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))/(sig*np.sqrt(2*np.pi))


# sigma_ = 0
# mh1= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0],[1,1]],ndims=2,tol=1e-30)

# fig,axs=mh1.MCMC2d(parameters=['x0','x1'],label_='deterministic orthodox')

# sigma_=0.25

# for sigma_ in [0.25,20.0,100.0]:    
#     mh_err= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0], [1,1]], ndims=2,tol=1e-35)
#     mh_err.MCMC2d(parameters=axs,label_='non-deterministic with std error='+str(sigma_))


# handles, labels = axs['x0']['x0'].get_legend_handles_labels()
# leg = fig.legend(handles, labels)
# fig.tight_layout()
# plt.show()


# plt.figure(0)
# x = np.linspace(0,1,3000)
  
# mean = 0.5, 
# sigg = 0.1
# y = gaussian(x, mu=mean, sig=sigg)



# axs['x0']['x0'].plot(x,y,label= 'gaussian')

# axs['x1']['x1'].plot(x,y,label= 'gaussian')


# handles, labels = axs['x0']['x1'].get_legend_handles_labels()
# leg = fig.legend(handles, labels)
# fig.tight_layout()
# plt.show()

# sys.exit(0)

#####################################################
'''%Metropolis hastings below'''


sigma_ = 0.0
mh= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0],[1,1]],ndims=2,Metropolis=True)

fig,axs=mh.MCMC2d(parameters=['x0','x1'],label_='deterministic Metropolis')

for sigma_ in [0.25,20.0,100.0]:    
    mh2= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0], [1,1]], ndims=2,Metropolis=True)
    mh2.MCMC2d(parameters=axs,label_='non-deterministic Metropolis with std error='+str(sigma_))
# with std error='+str(sigma_))


# x = np.linspace(0,1,3000)

# mean = 0.5, 
# sigg = 0.1
# y = gaussian(x, mu=mean, sig=sigg)

# axs['x0']['x0'].plot(x,y,color='purple')
    


# axs['x1']['x1'].plot(x,y,color='purple')
    


handles, labels = axs['x0']['x0'].get_legend_handles_labels()
leg = fig.legend(handles, labels)
fig.tight_layout()
plt.show()


plt.figure(0)

# plt.hist(mh1.logZ_int(200),label= 'ORTHODOX', alpha=0.5)
# plt.hist(mh2.logZ_int(200),label= 'MCMC',alpha=0.5)

# plt.legend(loc="upper left")








# # df = pd.DataFrame({
# #     'x_vals':x_
# # })
# # df['Actual Gaussian']=y

# # df.plot(x=x_,y='Actual Gaussian',ax=axs['x0']['x0'],color='purple')

# # df.plot(x=x_,y='Actual Gaussian',ax=axs['x1']['x1'],color='purple')

# %%
sigma_=2
x=  np.linspace(0,1,3000)
y=np.zeros(len(x))
for g in range(len(x)):
    y[g]=loglikelihood(x[g])
plt.scatter(x,y)

# %%
sigma_=100
x=  np.linspace(0,1,3000)
y=np.zeros(len(x))
for g in range(len(x)):
    y[g]=loglikelihood(x[g])
plt.plot(x,y)

# %%
sigma_=0
def multi_sampler(loglikelihood,x):
    multi_samples=100
    avg_val = np.mean([loglikelihood(x) for u in range(multi_samples)])
    return avg_val
        
sigma_=0

x=  np.linspace(0,1,3000)
y=np.zeros(len(x))
for g in range(len(x)):
    y[g]= multi_sampler(loglikelihood=loglikelihood,x=x[g])
plt.scatter(x,y)
# Out:
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0

# %%
sigma_=2
def multi_sampler(loglikelihood,x):
    multi_samples=100
    avg_val = np.mean([loglikelihood(x) for u in range(multi_samples)])
    return avg_val
        
sigma_=2

x=  np.linspace(0,1,3000)
y=np.zeros(len(x))
for g in range(len(x)):
    y[g]= multi_sampler(loglikelihood=loglikelihood,x=x[g])
plt.scatter(x,y)
# Out:
# loglikelihood is using sigma_ as2
# loglikelihood is using sigma_ as2
# loglikelihood is using sigma_ as2
# loglikelihood is using sigma_ as2
# loglikelihood is using sigma_ as2
# loglikelihood is using sigma_ as2

# %%
sigma_=0.25
x=  np.linspace(0,1,3000)
y=np.zeros(len(x))
for g in range(len(x)):
    y[g]=loglikelihood(x[g])
plt.scatter(x,y)
sigma_=0.25
x=  np.linspace(0,1,3000)
y=np.zeros(len(x))
for g in range(len(x)):
    y[g]=loglikelihood(x[g])

# %%
sigma_=2
def multi_sampler(loglikelihood,x):
    multi_samples=100
    avg_val = np.mean([loglikelihood(x) for u in range(multi_samples)])
    return avg_val

x=  np.linspace(0,1,3000)
y=np.zeros(len(x))
for g in range(len(x)):
    y[g]= multi_sampler(loglikelihood=loglikelihood,x=x[g])

sigma_=2
x=  np.linspace(0,1,3000)
y1=np.zeros(len(x))
for g in range(len(x)):
    y1[g]=loglikelihood(x[g])
plt.scatter(x,y1)
plt.scatter(x,y)
# Out:
# loglikelihood is using sigma_ as2
# loglikelihood is using sigma_ as2
# loglikelihood is using sigma_ as2
# loglikelihood is using sigma_ as2

# %%
sigma_=20
x=  np.linspace(0,1,3000)
y=np.zeros(len(x))
for g in range(len(x)):
    y[g]=loglikelihood(x[g])
plt.scatter(x,y)

# %%
sigma_=20
def multi_sampler(loglikelihood,x):
    multi_samples=1000
    avg_val = np.mean([loglikelihood(x) for u in range(multi_samples)])
    return avg_val
        
sigma_=20

x=  np.linspace(0,1,3000)
y=np.zeros(len(x))
for g in range(len(x)):
    y[g]= multi_sampler(loglikelihood=loglikelihood,x=x[g])
plt.scatter(x,y)
# Out:
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20

# %%
sigma_=20
def multi_sampler(loglikelihood,x):
    multi_samples=1000
    avg_val = np.mean([loglikelihood(x) for u in range(multi_samples)])
    return avg_val
        
sigma_=20

x=  np.linspace(0,1,3000)
y=np.zeros(len(x))
for g in range(len(x)):
    y[g]= multi_sampler(loglikelihood=loglikelihood,x=x[g])

sigma_=0
x=  np.linspace(0,1,3000)
y1=np.zeros(len(x))
for g in range(len(x)):
    y1[g]=loglikelihood(x[g])
plt.scatter(x,y)
plt.scatter(x,y1)
print(np.std(y1-y))
# Out:
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# 0.6472268131091354

# %%
sigma_=2
def multi_sampler(loglikelihood,x):
    multi_samples=100
    avg_val = np.mean([loglikelihood(x) for u in range(multi_samples)])
    return avg_val
        
sigma_=2

x=  np.linspace(0,1,3000)
y=np.zeros(len(x))
for g in range(len(x)):
    y[g]= multi_sampler(loglikelihood=loglikelihood,x=x[g])

sigma_=0
x=  np.linspace(0,1,3000)
y1=np.zeros(len(x))
for g in range(len(x)):
    y1[g]=loglikelihood(x[g])
plt.scatter(x,y)
plt.scatter(x,y1)
print(np.std(y1-y))
# Out:
# loglikelihood is using sigma_ as2
# loglikelihood is using sigma_ as2
# loglikelihood is using sigma_ as2
# loglikelihood is using sigma_ as2
# 0.19866290083851065

# %%
sigma_=20
def multi_sampler(loglikelihood,x):
    multi_samples=100
    avg_val = np.mean([loglikelihood(x) for u in range(multi_samples)])
    return avg_val
        
sigma_=20

x=  np.linspace(0,1,3000)
y=np.zeros(len(x))
for g in range(len(x)):
    y[g]= multi_sampler(loglikelihood=loglikelihood,x=x[g])
plt.scatter(x,y)
# Out:
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20
# loglikelihood is using sigma_ as20

# %%
sigma_=0.25
def multi_sampler(loglikelihood,x):
    multi_samples=1
    avg_val = np.mean([loglikelihood(x) for u in range(multi_samples)])
    return avg_val
        
sigma_=.25

x=  np.linspace(0,1,3000)
y=np.zeros(len(x))
for g in range(len(x)):
    y[g]= multi_sampler(loglikelihood=loglikelihood,x=x[g])

sigma_=0
x=  np.linspace(0,1,3000)
y1=np.zeros(len(x))
for g in range(len(x)):
    y1[g]=loglikelihood(x[g])
plt.scatter(x,y)
plt.scatter(x,y1)
print(np.std(y1-y))
# Out:
# 0.2497418939674864

# %%
sigma_=1000
x=  np.linspace(0,1,3000)
y=np.zeros(len(x))
for g in range(len(x)):
    y[g]=loglikelihood(x[g])
plt.plot(x,y)

# %%
def loglikelihood(x):
    mean = np.array([0.5, 0.5])
    cov = np.array([[0.01, 0.0], [0.0, 0.01 ]])
    logL = multivariate_normal.logpdf(x, mean=mean, cov=cov) + np.random.rand()*sigma_
    prob = np.random.rand()
    if prob>0.99999: 
        print('loglikelihood is using sigma_ as'+str(sigma_))
    return logL

# %%
sigma_=1000
x=  np.linspace(0,1,3000)
y=np.zeros(len(x))
for g in range(len(x)):
    y[g]=loglikelihood(x[g])
plt.plot(x,y)

# %%
sigma_=10000
x=  np.linspace(0,1,3000)
y=np.zeros(len(x))
for g in range(len(x)):
    y[g]=loglikelihood(x[g])
plt.plot(x,y)

# %%
from nestedsampling.samplers import NSrun
import numpy as np
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
import sys
import pandas as pd

def loglikelihood(x):
    mean = np.array([0.5, 0.5])
    cov = np.array([[0.01, 0.0], [0.0, 0.01 ]])
    logL = multivariate_normal.logpdf(x, mean=mean, cov=cov) + np.random.normal(0,sigma_)
    prob = np.random.rand()
    if prob>0.99999: 
        print('loglikelihood is using sigma_ as'+str(sigma_))
    return logL


def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))/(sig*np.sqrt(2*np.pi))


fig,axs=mh1.MCMC2d(parameters=['x0','x1'],label_='deterministic anesthetic.MCMCSamples orthodox')
mh1.NS2d(parameters=axs,label_='deterministic anesthetic.NestedSamples orthodox')
# sigma_=0.25

# for sigma_ in [0.25,20.0,100.0]:    
#     mh_err= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0], [1,1]], ndims=2,tol=1e-35)
#     mh_err.MCMC2d(parameters=axs,label_='non-deterministic with std error='+str(sigma_))


# handles, labels = axs['x0']['x0'].get_legend_handles_labels()
# leg = fig.legend(handles, labels)
# fig.tight_layout()
# plt.show()


# plt.figure(0)
# x = np.linspace(0,1,3000)
  
# mean = 0.5, 
# sigg = 0.1
# y = gaussian(x, mu=mean, sig=sigg)



# axs['x0']['x0'].plot(x,y,label= 'gaussian')

# axs['x1']['x1'].plot(x,y,label= 'gaussian')


# handles, labels = axs['x0']['x1'].get_legend_handles_labels()
# leg = fig.legend(handles, labels)
# fig.tight_layout()
# plt.show()

# sys.exit(0)

#####################################################
'''%Metropolis hastings below'''


sigma_ = 0.0
mh= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0],[1,1]],ndims=2,Metropolis=True)

mh.MCMC2d(parameters=axs,label_='deterministic anesthetic.MCMCSamples Metropolis')
mh.NS2d(parameters=axs,label_='deterministic anesthetic.NestedSamples Metropolis')
# sigma_=0.25


# x = np.linspace(0,1,3000)

# mean = 0.5, 
# sigg = 0.1
# y = gaussian(x, mu=mean, sig=sigg)

# axs['x0']['x0'].plot(x,y,color='purple')
    


# axs['x1']['x1'].plot(x,y,color='purple')
    


handles, labels = axs['x0']['x0'].get_legend_handles_labels()
leg = fig.legend(handles, labels)
fig.tight_layout()
plt.show()


plt.figure(0)

# plt.hist(mh1.logZ_int(200),label= 'ORTHODOX', alpha=0.5)
# plt.hist(mh2.logZ_int(200),label= 'MCMC',alpha=0.5)

# plt.legend(loc="upper left")








# # df = pd.DataFrame({
# #     'x_vals':x_
# # })
# # df['Actual Gaussian']=y

# # df.plot(x=x_,y='Actual Gaussian',ax=axs['x0']['x0'],color='purple')

# # df.plot(x=x_,y='Actual Gaussian',ax=axs['x1']['x1'],color='purple')
# Out:
# tolerance chosen as1e-30
#  56%|██████████████████████▌                 | 774/1375 [00:04<00:16, 36.73it/s]
# loglikelihood is using sigma_ as0
#  64%|█████████████████████████▍              | 875/1375 [00:08<00:25, 19.93it/s]
# loglikelihood is using sigma_ as0
#  66%|██████████████████████████▏             | 902/1375 [00:09<00:28, 16.50it/s]
# loglikelihood is using sigma_ as0
#  71%|████████████████████████████▍           | 977/1375 [00:18<00:37, 10.57it/s]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  73%|█████████████████████████████           | 998/1375 [00:22<01:04,  5.83it/s]
# loglikelihood is using sigma_ as0
#  73%|████████████████████████████▍          | 1004/1375 [00:23<00:52,  7.05it/s]
# loglikelihood is using sigma_ as0
#  74%|████████████████████████████▉          | 1021/1375 [00:26<01:02,  5.67it/s]
# loglikelihood is using sigma_ as0
#  74%|█████████████████████████████          | 1023/1375 [00:27<01:44,  3.38it/s]
# loglikelihood is using sigma_ as0
#  78%|██████████████████████████████▍        | 1072/1375 [00:39<01:23,  3.63it/s]
# loglikelihood is using sigma_ as0
#  79%|██████████████████████████████▉        | 1089/1375 [00:44<01:46,  2.68it/s]
# loglikelihood is using sigma_ as0
#  79%|██████████████████████████████▉        | 1091/1375 [00:45<02:31,  1.87it/s]
# loglikelihood is using sigma_ as0
#  84%|████████████████████████████████▊      | 1156/1375 [01:09<01:18,  2.78it/s]
# loglikelihood is using sigma_ as0
#  84%|████████████████████████████████▉      | 1160/1375 [01:11<01:12,  2.97it/s]
# loglikelihood is using sigma_ as0
#  86%|█████████████████████████████████▍     | 1177/1375 [01:19<02:32,  1.30it/s]
# loglikelihood is using sigma_ as0
#  86%|█████████████████████████████████▋     | 1188/1375 [01:26<01:50,  1.69it/s]
# loglikelihood is using sigma_ as0
#  87%|█████████████████████████████████▊     | 1193/1375 [01:29<01:43,  1.75it/s]
# loglikelihood is using sigma_ as0
#  88%|██████████████████████████████████▍    | 1216/1375 [01:39<00:54,  2.93it/s]
# loglikelihood is using sigma_ as0
#  89%|██████████████████████████████████▌    | 1218/1375 [01:41<01:20,  1.95it/s]
# loglikelihood is using sigma_ as0
#  89%|██████████████████████████████████▉    | 1230/1375 [01:50<01:40,  1.45it/s]
# loglikelihood is using sigma_ as0
#  90%|███████████████████████████████████    | 1234/1375 [01:54<02:28,  1.05s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  91%|███████████████████████████████████▎   | 1245/1375 [02:02<01:23,  1.56it/s]
# loglikelihood is using sigma_ as0
#  91%|███████████████████████████████████▍   | 1249/1375 [02:05<01:19,  1.59it/s]
# loglikelihood is using sigma_ as0
#  91%|███████████████████████████████████▌   | 1253/1375 [02:07<01:04,  1.89it/s]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  91%|███████████████████████████████████▌   | 1255/1375 [02:11<02:23,  1.20s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  91%|███████████████████████████████████▋   | 1257/1375 [02:15<02:56,  1.49s/it]
# loglikelihood is using sigma_ as0
#  91%|███████████████████████████████████▋   | 1258/1375 [02:16<02:40,  1.37s/it]
# loglikelihood is using sigma_ as0
#  93%|████████████████████████████████████▎  | 1279/1375 [02:32<00:52,  1.83it/s]
# loglikelihood is using sigma_ as0
#  93%|████████████████████████████████████▎  | 1280/1375 [02:33<01:27,  1.09it/s]
# loglikelihood is using sigma_ as0
#  94%|████████████████████████████████████▍  | 1286/1375 [02:45<02:15,  1.52s/it]
# loglikelihood is using sigma_ as0
#  94%|████████████████████████████████████▌  | 1291/1375 [02:52<02:03,  1.47s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  94%|████████████████████████████████████▋  | 1295/1375 [02:58<01:46,  1.34s/it]
# loglikelihood is using sigma_ as0
#  94%|████████████████████████████████████▊  | 1297/1375 [03:02<02:03,  1.58s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  94%|████████████████████████████████████▊  | 1299/1375 [03:08<03:04,  2.43s/it]
# loglikelihood is using sigma_ as0
#  95%|████████████████████████████████████▉  | 1301/1375 [03:10<02:04,  1.69s/it]
# loglikelihood is using sigma_ as0
#  95%|█████████████████████████████████████▏ | 1310/1375 [03:22<01:26,  1.32s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  95%|█████████████████████████████████████▏ | 1312/1375 [03:23<01:11,  1.14s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  96%|█████████████████████████████████████▎ | 1314/1375 [03:30<01:55,  1.89s/it]
# loglikelihood is using sigma_ as0
#  96%|█████████████████████████████████████▍ | 1319/1375 [03:35<00:57,  1.02s/it]
# loglikelihood is using sigma_ as0
#  97%|█████████████████████████████████████▋ | 1330/1375 [04:06<02:27,  3.27s/it]
# loglikelihood is using sigma_ as0
# loglikelihood is using sigma_ as0
#  97%|█████████████████████████████████████▊ | 1332/1375 [04:14<02:27,  3.43s/it]
# loglikelihood is using sigma_ as0
#  98%|██████████████████████████████████████ | 1343/1375 [04:41<00:49,  1.55s/it]
# loglikelihood is using sigma_ as0
#  98%|██████████████████████████████████████▏| 1346/1375 [04:48<01:03,  2.20s/it]
# loglikelihood is using sigma_ as0
#  98%|██████████████████████████████████████▎| 1349/1375 [04:55<00:55,  2.14s/it]
# loglikelihood is using sigma_ as0
#  99%|██████████████████████████████████████▍| 1357/1375 [05:13<00:35,  1.96s/it]
# loglikelihood is using sigma_ as0
#  99%|██████████████████████████████████████▊| 1367/1375 [05:43<00:29,  3.74s/it]
# loglikelihood is using sigma_ as0
# 100%|██████████████████████████████████████▉| 1371/1375 [05:49<00:07,  1.93s/it]
# loglikelihood is using sigma_ as0
# 100%|██████████████████████████████████████▉| 1374/1375 [06:04<00:03,  3.22s/it]
# loglikelihood is using sigma_ as0
# 100%|███████████████████████████████████████| 1375/1375 [06:09<00:00,  3.72it/s]
# -13484.093318229234should be same as-0.007165528952205236
# tolerance chosen as1e-30
# 100%|██████████████████████████████████████| 1375/1375 [00:05<00:00, 252.72it/s]
# random walk steps are12
# -13201.807898527435should be same as0.004585054847566106

# %%
fig,axs=mh1.MCMC2d(parameters=['x0','x1'],label_='deterministic anesthetic.MCMCSamples orthodox')
mh1.NS2d(parameters=axs,label_='deterministic anesthetic.NestedSamples orthodox')
# sigma_=0.25

# for sigma_ in [0.25,20.0,100.0]:    
#     mh_err= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0], [1,1]], ndims=2,tol=1e-35)
#     mh_err.MCMC2d(parameters=axs,label_='non-deterministic with std error='+str(sigma_))


# handles, labels = axs['x0']['x0'].get_legend_handles_labels()
# leg = fig.legend(handles, labels)
# fig.tight_layout()
# plt.show()


# plt.figure(0)
# x = np.linspace(0,1,3000)
  
# mean = 0.5, 
# sigg = 0.1
# y = gaussian(x, mu=mean, sig=sigg)



# axs['x0']['x0'].plot(x,y,label= 'gaussian')

# axs['x1']['x1'].plot(x,y,label= 'gaussian')


# handles, labels = axs['x0']['x1'].get_legend_handles_labels()
# leg = fig.legend(handles, labels)
# fig.tight_layout()
# plt.show()

# sys.exit(0)

#####################################################
'''%Metropolis hastings below'''


sigma_ = 0.0
mh= NSrun(loglikelihood=loglikelihood,prior_bounds=[[0,0],[1,1]],ndims=2,Metropolis=True)

mh.MCMC2d(parameters=axs,label_='deterministic anesthetic.MCMCSamples Metropolis')
mh.NS2d(parameters=axs,label_='deterministic anesthetic.NestedSamples Metropolis')
# sigma_=0.25


# x = np.linspace(0,1,3000)

# mean = 0.5, 
# sigg = 0.1
# y = gaussian(x, mu=mean, sig=sigg)

# axs['x0']['x0'].plot(x,y,color='purple')
    


# axs['x1']['x1'].plot(x,y,color='purple')
    


handles, labels = axs['x0']['x0'].get_legend_handles_labels()
leg = fig.legend(handles, labels)
fig.tight_layout()
plt.show()


plt.figure(0)

# plt.hist(mh1.logZ_int(200),label= 'ORTHODOX', alpha=0.5)
# plt.hist(mh2.logZ_int(200),label= 'MCMC',alpha=0.5)

# plt.legend(loc="upper left")








# # df = pd.DataFrame({
# #     'x_vals':x_
# # })
# # df['Actual Gaussian']=y

# # df.plot(x=x_,y='Actual Gaussian',ax=axs['x0']['x0'],color='purple')

# # df.plot(x=x_,y='Actual Gaussian',ax=axs['x1']['x1'],color='purple')
# Out:
# tolerance chosen as1e-30
# 100%|██████████████████████████████████████| 1375/1375 [00:05<00:00, 252.08it/s]
# random walk steps are12
# -13073.846605591525should be same as0.09911884081055522
